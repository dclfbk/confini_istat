# %%
import geopandas as gpd
import pandas as pd
import numpy as np
import requests, zipfile, io, os
import shutil

# %%
zip_file_url='http://www.istat.it/storage/cartografia/confini_amministrativi/generalizzati/Limiti01012018_g.zip'
maindir='Limiti01012018_g' 
r = requests.get(zip_file_url)
z = zipfile.ZipFile(io.BytesIO(r.content))
z.extractall()

# %%
dirs = os.listdir(maindir)
heads = ['rip','reg','prov','com']
def getDir(dirs,head):
    rname = None
    for name in dirs:
        if name.lower().startswith(head):
            rname = name
            break
    return rname

# %%
# regioni
dirRegion = getDir(dirs,'reg')
regions = os.listdir(os.path.join(maindir,dirRegion))

shp_region = None
for region in regions:
    if region.rfind("shp") > -1:
        shp_region = region
        break
regioni = gpd.read_file(os.path.join(maindir,dirRegion,shp_region))
regioni = regioni[["COD_REG","DEN_REG","geometry"]]
regioni = regioni.rename(index=str, columns={'COD_REG': 'id', 'DEN_REG': 'name','geometry':'geometry'})
regioni = regioni.to_crs({'init': 'epsg:4326'})

# %%
# province
dirProvince = getDir(dirs,'prov')
provinces = os.listdir(os.path.join(maindir,dirProvince))

shp_province = None
for province in provinces:
    if province.rfind("shp") > -1:
        shp_province = province
        break
province = gpd.read_file(os.path.join(maindir,dirProvince,shp_province))
province.loc[(province['DEN_PROV'] == "-") & (province['DEN_PCM'] != '-'), ['DEN_PROV']] = province['DEN_PCM']
province = province[["COD_REG","COD_PROV","DEN_PROV","SIGLA","geometry"]]
province = province.rename(index=str, columns={'COD_PROV':'id','COD_REG': 'id_reg', 'DEN_REG': 'name_region','DEN_PROV':'name','SIGLA':'sigla','geometry':'geometry'})
province = province.to_crs({'init': 'epsg:4326'})

# %%
# comuni
dirComuni = getDir(dirs,'com')
comuni = os.listdir(os.path.join(maindir,dirComuni))
shp_comuni = None
for comune in comuni:
    if comune.rfind("shp") > -1:
        shp_comuni = comune
        break
comuni = gpd.read_file(os.path.join(maindir,dirComuni,shp_comuni))
comuni = comuni[["COD_REG","COD_PROV","PRO_COM","COMUNE","geometry"]]
comuni = comuni.rename(index=str, columns={'COD_PROV':'id_prov','COD_REG': 'id_reg', 'PRO_COM': 'id','COMUNE':'name','geometry':'geometry'})
comuni = comuni.to_crs({'init': 'epsg:4326'})

# %%
# crea directory data
if os.path.exists('geojson'):
    shutil.rmtree("geojson")
os.makedirs("geojson")
filename="regions.json"
regioni.to_file(os.path.join("geojson",filename), driver="GeoJSON")

# %%
# crea province
for id_reg in regioni.id:
    regprov = os.path.join("geojson",str(id_reg))
    os.makedirs(regprov)
    provincia = province[province.id_reg == id_reg]
    fileprovinces = os.path.join(regprov,"provinces.json")
    print(fileprovinces)
    provincia.to_file(fileprovinces, driver="GeoJSON")
    for id_prov in provincia.id:
        provcom = os.path.join("geojson",str(id_reg),str(id_prov))
        filemuncipalities = os.path.join(provcom,"muncipalities.json")
        print(filemuncipalities)
        os.makedirs(provcom)
        comune = comuni[(comuni.id_prov == id_prov) & (comuni.id_reg == id_reg)]
        comune.to_file(filemuncipalities, driver="GeoJSON")
shutil.rmtree(maindir)
# Out:
# geojson/1/provinces.json
# geojson/1/1/muncipalities.json
# geojson/1/2/muncipalities.json
# geojson/1/3/muncipalities.json
# geojson/1/4/muncipalities.json
# geojson/1/5/muncipalities.json
# geojson/1/6/muncipalities.json
# geojson/1/96/muncipalities.json
# geojson/1/103/muncipalities.json
# geojson/2/provinces.json
# geojson/2/7/muncipalities.json
# geojson/3/provinces.json
# geojson/3/12/muncipalities.json
# geojson/3/13/muncipalities.json
# geojson/3/14/muncipalities.json
# geojson/3/15/muncipalities.json
# geojson/3/16/muncipalities.json
# geojson/3/17/muncipalities.json
# geojson/3/18/muncipalities.json
# geojson/3/19/muncipalities.json
# geojson/3/20/muncipalities.json
# geojson/3/97/muncipalities.json
# geojson/3/98/muncipalities.json
# geojson/3/108/muncipalities.json
# geojson/4/provinces.json
# geojson/4/21/muncipalities.json
# geojson/4/22/muncipalities.json
# geojson/5/provinces.json
# geojson/5/23/muncipalities.json
# geojson/5/24/muncipalities.json
# geojson/5/25/muncipalities.json
# geojson/5/26/muncipalities.json
# geojson/5/27/muncipalities.json
# geojson/5/28/muncipalities.json
# geojson/5/29/muncipalities.json
# geojson/6/provinces.json
# geojson/6/30/muncipalities.json
# geojson/6/31/muncipalities.json
# geojson/6/32/muncipalities.json
# geojson/6/93/muncipalities.json
# geojson/7/provinces.json
# geojson/7/8/muncipalities.json
# geojson/7/9/muncipalities.json
# geojson/7/10/muncipalities.json
# geojson/7/11/muncipalities.json
# geojson/8/provinces.json
# geojson/8/33/muncipalities.json
# geojson/8/34/muncipalities.json
# geojson/8/35/muncipalities.json
# geojson/8/36/muncipalities.json
# geojson/8/37/muncipalities.json
# geojson/8/38/muncipalities.json
# geojson/8/39/muncipalities.json
# geojson/8/40/muncipalities.json
# geojson/8/99/muncipalities.json
# geojson/9/provinces.json
# geojson/9/45/muncipalities.json
# geojson/9/46/muncipalities.json
# geojson/9/47/muncipalities.json
# geojson/9/48/muncipalities.json
# geojson/9/49/muncipalities.json
# geojson/9/50/muncipalities.json
# geojson/9/51/muncipalities.json
# geojson/9/52/muncipalities.json
# geojson/9/53/muncipalities.json
# geojson/9/100/muncipalities.json
# geojson/10/provinces.json
# geojson/10/54/muncipalities.json
# geojson/10/55/muncipalities.json
# geojson/11/provinces.json
# geojson/11/41/muncipalities.json
# geojson/11/42/muncipalities.json
# geojson/11/43/muncipalities.json
# geojson/11/44/muncipalities.json
# geojson/11/109/muncipalities.json
# geojson/12/provinces.json
# geojson/12/56/muncipalities.json
# geojson/12/57/muncipalities.json
# geojson/12/58/muncipalities.json
# geojson/12/59/muncipalities.json
# geojson/12/60/muncipalities.json
# geojson/13/provinces.json
# geojson/13/66/muncipalities.json
# geojson/13/67/muncipalities.json
# geojson/13/68/muncipalities.json
# geojson/13/69/muncipalities.json
# geojson/14/provinces.json
# geojson/14/70/muncipalities.json
# geojson/14/94/muncipalities.json
# geojson/15/provinces.json
# geojson/15/61/muncipalities.json
# geojson/15/62/muncipalities.json
# geojson/15/63/muncipalities.json
# geojson/15/64/muncipalities.json
# geojson/15/65/muncipalities.json
# geojson/16/provinces.json
# geojson/16/71/muncipalities.json
# geojson/16/72/muncipalities.json
# geojson/16/73/muncipalities.json
# geojson/16/74/muncipalities.json
# geojson/16/75/muncipalities.json
# geojson/16/110/muncipalities.json
# geojson/17/provinces.json
# geojson/17/76/muncipalities.json
# geojson/17/77/muncipalities.json
# geojson/18/provinces.json
# geojson/18/78/muncipalities.json
# geojson/18/79/muncipalities.json
# geojson/18/80/muncipalities.json
# geojson/18/101/muncipalities.json
# geojson/18/102/muncipalities.json
# geojson/19/provinces.json
# geojson/19/81/muncipalities.json
# geojson/19/82/muncipalities.json
# geojson/19/83/muncipalities.json
# geojson/19/84/muncipalities.json
# geojson/19/85/muncipalities.json
# geojson/19/86/muncipalities.json
# geojson/19/87/muncipalities.json
# geojson/19/88/muncipalities.json
# geojson/19/89/muncipalities.json
# geojson/20/provinces.json
# geojson/20/90/muncipalities.json
# geojson/20/91/muncipalities.json
# geojson/20/92/muncipalities.json
# geojson/20/95/muncipalities.json
# geojson/20/111/muncipalities.json
